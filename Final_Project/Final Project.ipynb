# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('NCAA_DATA_v2.csv')
df2 = df.dropna()
print df2.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Season Seed  Team       Team_Name  Slot  StrongSeed  \
# 0   2003-W01  2003-R1W1    2003  W01  1328        Oklahoma  R1W1           1
# 1   2003-W02  2003-R1W2    2003  W02  1448     Wake Forest  R1W2           1
# 2   2003-W03  2003-R1W3    2003  W03  1393        Syracuse  R1W3           1
# 3   2003-W04  2003-R1W4    2003  W04  1257      Louisville  R1W4           1
# 4   2003-W05  2003-R1W5    2003  W05  1280  Mississippi St  R1W5           1
#
#      DayZero  Daynum  ...   Lfga3  Lftm  Lfta   Lor   Ldr  Last   Lto  Lstl  \
# 0  11/4/2002   136.0  ...    20.0   6.0   8.0   7.0  22.0   8.0  18.0   7.0
# 1  11/4/2002   137.0  ...    10.0  20.0  28.0  13.0  25.0   7.0  15.0  12.0
# 2  11/4/2002   137.0  ...    21.0  15.0  18.0  14.0  14.0  16.0  11.0   9.0
# 3  11/4/2002   137.0  ...    21.0  14.0  22.0   8.0  21.0  11.0  18.0   5.0
# 4  11/4/2002   137.0  ...    21.0   8.0  14.0   8.0  22.0  10.0  10.0   6.0
#
#    Lblk   Lpf
# 0   2.0  23.0
# 1   4.0  20.0
# ...

# %%
print df2.describe()
# Out:
#             Season         Team  StrongSeed      Daynum       Wteam  \
# count   860.000000   860.000000  860.000000  860.000000  860.000000
# mean   2009.069767  1293.186047    0.516279  136.355814    0.510465
# std       3.752502   106.502610    0.500026    0.726291    0.500181
# min    2003.000000  1102.000000    0.000000  134.000000    0.000000
# 25%    2006.000000  1207.000000    0.000000  136.000000    0.000000
# 50%    2009.000000  1293.000000    1.000000  136.000000    1.000000
# 75%    2012.000000  1393.000000    1.000000  137.000000    1.000000
# max    2015.000000  1462.000000    1.000000  137.000000    1.000000
#
#            Wscore       Lteam      Lscore       Numot        Wfgm     ...      \
# count  860.000000  860.000000  860.000000  860.000000  860.000000     ...
# mean    74.101163    0.489535   61.960465    0.063953   25.937209     ...
# std     10.561434    0.500181   10.353061    0.280285    4.829166     ...
# ...

# %%
df.corr()
# Out:
#               Season      Team  StrongSeed    Daynum     Wteam    Wscore  \
# Season      1.000000 -0.006725    0.018568 -0.086005  0.005813 -0.059984
# Team       -0.006725  1.000000   -0.035701  0.044353  0.040480 -0.083368
# StrongSeed  0.018568 -0.035701    1.000000  0.012882  0.448492  0.013245
# Daynum     -0.086005  0.044353    0.012882  1.000000  0.002556 -0.000145
# Wteam       0.005813  0.040480    0.448492  0.002556  1.000000  0.018421
# Wscore     -0.059984 -0.083368    0.013245 -0.000145  0.018421  1.000000
# Lteam      -0.005813 -0.040480   -0.448492 -0.002556 -1.000000 -0.018421
# Lscore     -0.046914 -0.062101   -0.010895 -0.032652 -0.004416  0.608059
# Numot      -0.003140  0.006855   -0.003284 -0.066164 -0.000628  0.110679
# Wfgm       -0.040808 -0.050914    0.011512 -0.013206  0.023888  0.822374
# Wfga       -0.092028  0.017991    0.004963 -0.082049  0.015241  0.511059
# Wfgm3      -0.119595 -0.012325    0.009991  0.034352  0.006850  0.333642
# ...

# %%
compact = pd.read_csv('RegularSeasonDetailedResults.csv')
print compact.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga ...   \
# 0    2003      10   1104      68   1328      62    N      0    27    58 ...
# 1    2003      10   1272      70   1393      63    N      0    26    62 ...
# 2    2003      11   1266      73   1437      61    N      0    24    58 ...
# 3    2003      11   1296      56   1457      50    N      0    18    38 ...
# 4    2003      11   1400      77   1208      71    N      0    30    61 ...
#
#    Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0     10    16    22   10   22     8   18     9     2   20
# 1     24     9    20   20   25     7   12     8     6   16
# 2     26    14    23   31   22     9   12     2     5   23
# 3     22     8    15   17   20     9   19     4     3   23
# 4     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
pd.crosstab(df2.Team, df2.Wteam)
# Out:
# Wteam  0.0  1.0
# Team
# 1102     2    0
# 1103     3    0
# 1104     3    2
# 1105     1    0
# 1106     3    0
# 1107     4    1
# 1110     3    0
# 1112     3    8
# 1113     1    2
# 1114     1    0
# 1115     0    1
# 1116     2    2
# 1120     0    1
# 1122     2    0
# 1124     2    3
# 1125     7    0
# 1127     1    0
# 1129     3    0
# 1130     1    4
# 1131     1    0
# 1133     0    1
# 1137     2    2
# 1138     1    0
# 1139     1    7
# 1140     7    3
# 1141     0    1
# 1142     0    1
# 1143     3    3
# 1148     1    0
# 1150     2    0
# ...    ...  ...
# 1424     4    2
# 1425     2    2
# 1426     1    0
# 1427     1    1
# 1428     2    3
# 1429     6    0
# 1431     3    0
# 1433     4    4
# 1434     3    0
# 1435     3    3
# 1436     3    2
# 1437     3    7
# 1438     1    3
# 1439     0    1
# 1443     2    3
# 1444     2    0
# 1447     1    0
# 1448     1    4
# 1449     1    5
# 1450     0    2
# 1451     3    0
# 1452     2    6
# 1454     2    2
# ...

# %%
df.groupby(['Team', 'Wteam']).sum()
# Out:
#             Season  StrongSeed  Daynum  Wscore  Lteam  Lscore  Numot   Wfgm  \
# Team Wteam
# 1102 0.0      4010           0   272.0   141.0    2.0   121.0    0.0   51.0
# 1103 0.0      6033           0   409.0   234.0    3.0   162.0    0.0   79.0
# 1104 0.0      6020           1   410.0   208.0    3.0   192.0    0.0   67.0
#      1.0      4010           1   272.0   155.0    0.0   149.0    0.0   52.0
# 1105 0.0      2005           1   134.0    79.0    1.0    69.0    0.0   29.0
# 1106 0.0      6024           2   405.0   224.0    3.0   165.0    0.0   73.0
# 1107 0.0      8041           0   548.0   298.0    4.0   237.0    0.0  109.0
#      1.0      2014           1   134.0    71.0    0.0    64.0    0.0   27.0
# 1110 0.0      6031           0   409.0   227.0    3.0   159.0    0.0   72.0
# 1112 0.0      6019           1   409.0   227.0    3.0   204.0    0.0   79.0
#      1.0     16076           7  1092.0   643.0    0.0   520.0    0.0  229.0
# ...
